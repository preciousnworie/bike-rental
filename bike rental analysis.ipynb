# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
day=pd.read_csv('day.csv')
day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
rentals_11 = day[day['yr']==0]
rentals_11
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 360      361  2011-12-27       1   0    12        0        2           1
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
rentals_11.iloc[:, [13,14]]
# Out:
#      casual  registered
# 0       331         654
# 1       131         670
# 2       120        1229
# 3       108        1454
# 4        82        1518
# ..      ...         ...
# 360     103        1059
# 361     255        2047
# 362     254        2169
# 363     491        2508
# 364     665        1820
#
# [365 rows x 2 columns]

# %%
rentals_11["casual"].sum()
# Out:
# 247252

# %%
rentals_11["registered"].sum()
# Out:
# 995851

# %%
labels="casual","registered"
sizes=[247252,995851]
colors=['yellow','blue']
explode=(0,0)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=100)
plt.axis('equal')
plt.title('Users of Bike Rentals')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
rentals_12= day[day['yr']==1]
rentals_12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 365      366  2012-01-01       1   1     1        0        0           0
# 366      367  2012-01-02       1   1     1        1        1           0
# 367      368  2012-01-03       1   1     1        0        2           1
# 368      369  2012-01-04       1   1     1        0        3           1
# 369      370  2012-01-05       1   1     1        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
rentals_12.iloc[:,[13,14]]
# Out:
#      casual  registered
# 365     686        1608
# 366     244        1707
# 367      89        2147
# 368      95        2273
# 369     140        3132
# ..      ...         ...
# 726     247        1867
# 727     644        2451
# 728     159        1182
# 729     364        1432
# 730     439        2290
#
# [366 rows x 2 columns]

# %%
rentals_12['casual'].sum()
# Out:
# 372765

# %%
rentals_12['registered'].sum()
# Out:
# 1676811

# %%
labels='casual','registered'
sizes=[372765,1676811]
colors=['yellow','blue']
explode=(0,0)

# %%
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=False,startangle=100)
plt.axis('equal')
plt.title('users of bike rental')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
rentals_11.iloc[:, [8,15]]
# Out:
#      weathersit   cnt
# 0             2   985
# 1             2   801
# 2             1  1349
# 3             1  1562
# 4             1  1600
# ..          ...   ...
# 360           2  1162
# 361           1  2302
# 362           1  2423
# 363           1  2999
# 364           1  2485
#
# [365 rows x 2 columns]

# %%
clear_11 = rentals_11[rentals_11['weathersit']==1]
clear_11
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 8          9  2011-01-09       1   0     1        0        0           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 359      360  2011-12-26       1   0    12        1        1           0
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
clear_11['cnt'].sum()
# Out:
# 835067

# %%
mist_11 = rentals_11[rentals_11['weathersit']==2]
mist_11
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 10        11  2011-01-11       1   0     1        0        2           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 350      351  2011-12-17       4   0    12        0        6           0
# 353      354  2011-12-20       4   0    12        0        2           1
# 354      355  2011-12-21       1   0    12        0        3           1
# 355      356  2011-12-22       1   0    12        0        4           1
# 360      361  2011-12-27       1   0    12        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
mist_11['cnt'].sum()
# Out:
# 382924

# %%
snow_11 = rentals_11[rentals_11['weathersit']==3]
snow_11
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 25        26  2011-01-26       1   0     1        0        3           1
# 68        69  2011-03-10       1   0     3        0        4           1
# 89        90  2011-03-31       2   0     3        0        4           1
# 105      106  2011-04-16       2   0     4        0        6           0
# 248      249  2011-09-06       3   0     9        0        2           1
# 249      250  2011-09-07       3   0     9        0        3           1
# 250      251  2011-09-08       3   0     9        0        4           1
# 284      285  2011-10-12       4   0    10        0        3           1
# 291      292  2011-10-19       4   0    10        0        3           1
# 301      302  2011-10-29       4   0    10        0        6           0
# 319      320  2011-11-16       4   0    11        0        3           1
# 324      325  2011-11-21       4   0    11        0        1           1
# ...

# %%
snow_11['cnt'].sum()
# Out:
# 25112

# %%
heavy_rain_11 = rentals_11[rentals_11['weathersit']==4]
heavy_rain_11
# Out:
# Empty DataFrame
# Columns: [instant, dteday, season, yr, mnth, holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed, casual, registered, cnt]
# Index: []

# %%
plt.bar(['clear','mist','snow','heavy rain'],[835067,382924,25112,0], color = ['red','yellow','purple','blue'])
plt.title('Rentage during different weathersit')
# Out:
# Text(0.5, 1.0, 'Rentage during different weathersit')

# %%
rentals_12.iloc[:, [8,15]]
# Out:
#      weathersit   cnt
# 365           1  2294
# 366           1  1951
# 367           1  2236
# 368           2  2368
# 369           1  3272
# ..          ...   ...
# 726           2  2114
# 727           2  3095
# 728           2  1341
# 729           1  1796
# 730           2  2729
#
# [366 rows x 2 columns]

# %%
clear_12= rentals_12[rentals_12['weathersit']==1]
clear_12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 365      366  2012-01-01       1   1     1        0        0           0
# 366      367  2012-01-02       1   1     1        1        1           0
# 367      368  2012-01-03       1   1     1        0        2           1
# 369      370  2012-01-05       1   1     1        0        4           1
# 370      371  2012-01-06       1   1     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 717      718  2012-12-18       4   1    12        0        2           1
# 718      719  2012-12-19       4   1    12        0        3           1
# 721      722  2012-12-22       1   1    12        0        6           0
# 722      723  2012-12-23       1   1    12        0        0           0
# 729      730  2012-12-30       1   1    12        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
clear_12['cnt'].sum()
# Out:
# 1422885

# %%
mist_12= rentals_12[rentals_12['weathersit']==2]
mist_12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 368      369  2012-01-04       1   1     1        0        3           1
# 373      374  2012-01-09       1   1     1        0        1           1
# 375      376  2012-01-11       1   1     1        0        3           1
# 376      377  2012-01-12       1   1     1        0        4           1
# 381      382  2012-01-17       1   1     1        0        2           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 724      725  2012-12-25       1   1    12        1        2           0
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
mist_12['cnt'].sum()
# Out:
# 613934

# %%
snow_12= rentals_12[rentals_12['weathersit']==3]
snow_12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 406      407  2012-02-11       1   1     2        0        6           0
# 477      478  2012-04-22       2   1     4        0        0           0
# 567      568  2012-07-21       3   1     7        0        6           0
# 640      641  2012-10-02       4   1    10        0        2           1
# 667      668  2012-10-29       4   1    10        0        1           1
# 725      726  2012-12-26       1   1    12        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 406           3  0.224167  0.210867  0.731250   0.289796     192        1977
# 477           3  0.396667  0.389504  0.835417   0.344546     120         907
# 567           3  0.595833  0.549912  0.865417   0.213300    1264        3195
# 640           3  0.590833  0.542333  0.871667   0.104475     315        4324
# ...

# %%
snow_12['cnt'].sum()
# Out:
# 12757

# %%
plt.bar(['clear','mist','snow','heavy rain'], [1422885,613934,12757, 0], color = ['red','yellow','purple','blue'] )
plt.title('Rentage during different weathersit')
# Out:
# Text(0.5, 1.0, 'Rentage during different weathersit')

# %%
spring_rents = rentals_11[rentals_11['season']==1]
spring_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 360      361  2011-12-27       1   0    12        0        2           1
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
spring_rents['cnt'].sum()
# Out:
# 150000

# %%
summer_rents = rentals_11[rentals_11['season']==2]
summer_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 79        80  2011-03-21       2   0     3        0        1           1
# 80        81  2011-03-22       2   0     3        0        2           1
# 81        82  2011-03-23       2   0     3        0        3           1
# 82        83  2011-03-24       2   0     3        0        4           1
# 83        84  2011-03-25       2   0     3        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 166      167  2011-06-16       2   0     6        0        4           1
# 167      168  2011-06-17       2   0     6        0        5           1
# 168      169  2011-06-18       2   0     6        0        6           0
# 169      170  2011-06-19       2   0     6        0        0           0
# 170      171  2011-06-20       2   0     6        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
summer_rents['cnt'].sum()
# Out:
# 347316

# %%
fall_rents = rentals_11[rentals_11['season']==3]
fall_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 171      172  2011-06-21       3   0     6        0        2           1
# 172      173  2011-06-22       3   0     6        0        3           1
# 173      174  2011-06-23       3   0     6        0        4           1
# 174      175  2011-06-24       3   0     6        0        5           1
# 175      176  2011-06-25       3   0     6        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 260      261  2011-09-18       3   0     9        0        0           0
# 261      262  2011-09-19       3   0     9        0        1           1
# 262      263  2011-09-20       3   0     9        0        2           1
# 263      264  2011-09-21       3   0     9        0        3           1
# 264      265  2011-09-22       3   0     9        0        4           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
fall_rents['cnt'].sum()
# Out:
# 419650

# %%
winter_rents = rentals_11[rentals_11['season']==4]
winter_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 265      266  2011-09-23       4   0     9        0        5           1
# 266      267  2011-09-24       4   0     9        0        6           0
# 267      268  2011-09-25       4   0     9        0        0           0
# 268      269  2011-09-26       4   0     9        0        1           1
# 269      270  2011-09-27       4   0     9        0        2           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 349      350  2011-12-16       4   0    12        0        5           1
# 350      351  2011-12-17       4   0    12        0        6           0
# 351      352  2011-12-18       4   0    12        0        0           0
# 352      353  2011-12-19       4   0    12        0        1           1
# 353      354  2011-12-20       4   0    12        0        2           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
winter_rents['cnt'].sum()
# Out:
# 326137

# %%
plt.bar(['Spring', 'Summer', 'Fall', 'Winter'], [150000, 347316, 419650, 326137], color = ['blue', 'red', 'green', 'yellow'])
plt.title('Rate of Total Rentage across Seasons')
# Out:
# Text(0.5, 1.0, 'Rate of Total Rentage across Seasons')

# %%
spring_season__12 = rentals_12[rentals_12["season"]==1]
spring_season__12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 365      366  2012-01-01       1   1     1        0        0           0
# 366      367  2012-01-02       1   1     1        1        1           0
# 367      368  2012-01-03       1   1     1        0        2           1
# 368      369  2012-01-04       1   1     1        0        3           1
# 369      370  2012-01-05       1   1     1        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
spring_season__12["cnt"].sum()
# Out:
# 321348

# %%
summer_season__12 = rentals_12[rentals_12["season"]==2]
summer_season__12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 445      446  2012-03-21       2   1     3        0        3           1
# 446      447  2012-03-22       2   1     3        0        4           1
# 447      448  2012-03-23       2   1     3        0        5           1
# 448      449  2012-03-24       2   1     3        0        6           0
# 449      450  2012-03-25       2   1     3        0        0           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 532      533  2012-06-16       2   1     6        0        6           0
# 533      534  2012-06-17       2   1     6        0        0           0
# 534      535  2012-06-18       2   1     6        0        1           1
# 535      536  2012-06-19       2   1     6        0        2           1
# 536      537  2012-06-20       2   1     6        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
summer_season__12["cnt"].sum()
# Out:
# 347316

# %%
fall_season__12 = rentals_12[rentals_12["season"]==3]
fall_season__12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 537      538  2012-06-21       3   1     6        0        4           1
# 538      539  2012-06-22       3   1     6        0        5           1
# 539      540  2012-06-23       3   1     6        0        6           0
# 540      541  2012-06-24       3   1     6        0        0           0
# 541      542  2012-06-25       3   1     6        0        1           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 626      627  2012-09-18       3   1     9        0        2           1
# 627      628  2012-09-19       3   1     9        0        3           1
# 628      629  2012-09-20       3   1     9        0        4           1
# 629      630  2012-09-21       3   1     9        0        5           1
# 630      631  2012-09-22       3   1     9        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
fall_season__12["cnt"].sum()
# Out:
# 641479

# %%
winter_season__12 = rentals_12[rentals_12["season"]==4]
winter_season__12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 631      632  2012-09-23       4   1     9        0        0           0
# 632      633  2012-09-24       4   1     9        0        1           1
# 633      634  2012-09-25       4   1     9        0        2           1
# 634      635  2012-09-26       4   1     9        0        3           1
# 635      636  2012-09-27       4   1     9        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 715      716  2012-12-16       4   1    12        0        0           0
# 716      717  2012-12-17       4   1    12        0        1           1
# 717      718  2012-12-18       4   1    12        0        2           1
# 718      719  2012-12-19       4   1    12        0        3           1
# 719      720  2012-12-20       4   1    12        0        4           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
winter_season__12["cnt"].sum()
# Out:
# 515476

# %%
plt.bar(["spring","summer","fall","winter"] , [321348,571273,641479,515476], color =["blue","red","green","yellow"])
plt.title('Rate of Total Rentage across Seasons')
# Out:
# Text(0.5, 1.0, 'Rate of Total Rentage across Seasons')

# %%
holiday_rents = rentals_11[rentals_11['workingday']==0]
holiday_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 14        15  2011-01-15       1   0     1        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 351      352  2011-12-18       4   0    12        0        0           0
# 357      358  2011-12-24       1   0    12        0        6           0
# 358      359  2011-12-25       1   0    12        0        0           0
# 359      360  2011-12-26       1   0    12        1        1           0
# 364      365  2011-12-31       1   0    12        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
holiday_rents['cnt'].sum()
# Out:
# 386839

# %%
weekday_rents = rentals_11[rentals_11['workingday']==1]
weekday_rents
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 356      357  2011-12-23       1   0    12        0        5           1
# 360      361  2011-12-27       1   0    12        0        2           1
# 361      362  2011-12-28       1   0    12        0        3           1
# 362      363  2011-12-29       1   0    12        0        4           1
# 363      364  2011-12-30       1   0    12        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
weekday_rents['cnt'].sum()
# Out:
# 856264

# %%
plt.bar(['Holiday', 'Weekdays'], [386839, 856264], color = ['chocolate', 'magenta'])
plt.title('Rate of Rent per Holiday/Weekday')
# Out:
# Text(0.5, 1.0, 'Rate of Rent per Holiday/Weekday')

# %%
holiday_season__12 = rentals_12[rentals_12["workingday"]==0]
holiday_season__12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 365      366  2012-01-01       1   1     1        0        0           0
# 366      367  2012-01-02       1   1     1        1        1           0
# 371      372  2012-01-07       1   1     1        0        6           0
# 372      373  2012-01-08       1   1     1        0        0           0
# 378      379  2012-01-14       1   1     1        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 721      722  2012-12-22       1   1    12        0        6           0
# 722      723  2012-12-23       1   1    12        0        0           0
# 724      725  2012-12-25       1   1    12        1        2           0
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
holiday_season__12["cnt"].sum()
# Out:
# 613430

# %%
weekday__12 = rentals_12[rentals_12["workingday"]==1]
weekday__12
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 367      368  2012-01-03       1   1     1        0        2           1
# 368      369  2012-01-04       1   1     1        0        3           1
# 369      370  2012-01-05       1   1     1        0        4           1
# 370      371  2012-01-06       1   1     1        0        5           1
# 373      374  2012-01-09       1   1     1        0        1           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 723      724  2012-12-24       1   1    12        0        1           1
# 725      726  2012-12-26       1   1    12        0        3           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
weekday__12["cnt"].sum()
# Out:
# 1436146

# %%
plt.bar(["Hoilday", "weekday"], [613430,1436146] , color = ["chocolate" , "magenta"])
plt.title('Rate of Rent per Holiday/Weekday')
# Out:
# Text(0.5, 1.0, 'Rate of Rent per Holiday/Weekday')
